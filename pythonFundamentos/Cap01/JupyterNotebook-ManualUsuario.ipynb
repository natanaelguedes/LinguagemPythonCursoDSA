# %% [markdown]
# # Manual Jupyter Notebook
#
# Pesquisa eleitoral

# %% [markdown]
# # Exemplo de gráficos de setores

# %% [markdown]
# ![](images/jupytertoolbar.png)

# %%
# import matplotlib.pyplot as plt
x = [10, 50, 30, 20]
labels = ['Surfing', 'Soccer', 'Baseball', 'Lacrosse']
fig, ax = plt.subplots()
ax.pie(x, labels=labels)
ax.pie(x, labels=labels, autopct='%.1f%%')
ax.set_title('Sport Popularity')
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# ------

# %% [markdown]
# * * *

# %% [markdown]
# _ _ _
